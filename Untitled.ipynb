# %% [raw]
# Iter: 100
# stage1_pafs_loss:     168.23064270019532
# stage1_heatmaps_loss: 392.3361758422852
# stage2_pafs_loss:     205.77613777160644
# stage2_heatmaps_loss: 244.80729801177978
# Iter: 200
# stage1_pafs_loss:     150.04515556335448
# stage1_heatmaps_loss: 77.1875936126709
# stage2_pafs_loss:     149.87886734008788
# stage2_heatmaps_loss: 69.44987342834473
# Iter: 300
# stage1_pafs_loss:     152.28260429382325
# stage1_heatmaps_loss: 71.06146671295166
# stage2_pafs_loss:     151.78451614379884
# stage2_heatmaps_loss: 69.37172561645508
# Iter: 400
# stage1_pafs_loss:     149.8747285461426
# stage1_heatmaps_loss: 69.4182532119751
# stage2_pafs_loss:     149.59097625732423
# stage2_heatmaps_loss: 68.56601089477539
# Iter: 500
# stage1_pafs_loss:     153.00930870056152
# stage1_heatmaps_loss: 71.09218463897705
# stage2_pafs_loss:     152.7441254425049
# stage2_heatmaps_loss: 70.2348526763916
# Iter: 600
# stage1_pafs_loss:     149.6480012512207
# stage1_heatmaps_loss: 69.26139030456542
# stage2_pafs_loss:     149.38386405944823
# stage2_heatmaps_loss: 68.45077514648438
# Iter: 700
# stage1_pafs_loss:     150.5365771484375
# stage1_heatmaps_loss: 69.23245346069336
# stage2_pafs_loss:     150.21533950805664
# stage2_heatmaps_loss: 68.40627620697022
# Iter: 800
# stage1_pafs_loss:     148.67597259521483
# stage1_heatmaps_loss: 67.54933769226074
# stage2_pafs_loss:     148.36015846252442
# stage2_heatmaps_loss: 66.61031116485596
# Iter: 900
# stage1_pafs_loss:     149.9758681488037
# stage1_heatmaps_loss: 67.84840602874756
# stage2_pafs_loss:     149.5765446472168
# stage2_heatmaps_loss: 66.83304992675781
# Iter: 1000
# stage1_pafs_loss:     150.4402631378174
# stage1_heatmaps_loss: 69.0821439743042
# stage2_pafs_loss:     149.90559143066406
# stage2_heatmaps_loss: 68.00188831329346
# Iter: 1100
# stage1_pafs_loss:     147.95932800292968
# stage1_heatmaps_loss: 67.11360767364502
# stage2_pafs_loss:     147.46246482849122
# stage2_heatmaps_loss: 66.02266220092774
# Iter: 1200
# stage1_pafs_loss:     152.26613159179686
# stage1_heatmaps_loss: 69.34326274871826
# stage2_pafs_loss:     151.65913459777832
# stage2_heatmaps_loss: 68.12092830657959
# Iter: 1300
# stage1_pafs_loss:     147.80275405883788
# stage1_heatmaps_loss: 66.87455249786377
# stage2_pafs_loss:     147.19087684631347
# stage2_heatmaps_loss: 65.63408866882324
# Iter: 1400
# stage1_pafs_loss:     151.13674896240235
# stage1_heatmaps_loss: 68.62011337280273
# stage2_pafs_loss:     150.41366180419922
# stage2_heatmaps_loss: 67.32445667266846
# Iter: 1500
# stage1_pafs_loss:     148.75196075439453
# stage1_heatmaps_loss: 67.89281307220459
# stage2_pafs_loss:     148.00321517944337
# stage2_heatmaps_loss: 66.47083206176758
# Iter: 1600
# stage1_pafs_loss:     149.06589538574218
# stage1_heatmaps_loss: 67.6401431274414
# stage2_pafs_loss:     148.2227912902832
# stage2_heatmaps_loss: 66.2762260055542
# Iter: 1700
# stage1_pafs_loss:     152.3511328125
# stage1_heatmaps_loss: 68.21309844970703
# stage2_pafs_loss:     151.46912078857423
# stage2_heatmaps_loss: 66.80790431976318
# Iter: 1800
# stage1_pafs_loss:     149.2599326324463
# stage1_heatmaps_loss: 66.94131912231445
# stage2_pafs_loss:     148.29303855895995
# stage2_heatmaps_loss: 65.44381504058838
# Iter: 1900
# stage1_pafs_loss:     148.71300827026369
# stage1_heatmaps_loss: 65.62252765655518
# stage2_pafs_loss:     147.80467193603516
# stage2_heatmaps_loss: 64.149856300354
# Iter: 2000
# stage1_pafs_loss:     148.55956413269044
# stage1_heatmaps_loss: 66.88897087097168
# stage2_pafs_loss:     147.47118423461913
# stage2_heatmaps_loss: 65.2552593612671
# Iter: 2100
# stage1_pafs_loss:     147.95591316223144
# stage1_heatmaps_loss: 66.2598719406128
# stage2_pafs_loss:     146.8251926422119
# stage2_heatmaps_loss: 64.61814720153808
# Iter: 2200
# stage1_pafs_loss:     149.78065811157228
# stage1_heatmaps_loss: 66.78682182312012
# stage2_pafs_loss:     148.59306716918945
# stage2_heatmaps_loss: 65.0611722946167
# Iter: 2300
# stage1_pafs_loss:     149.1847528076172
# stage1_heatmaps_loss: 66.09310600280762
# stage2_pafs_loss:     148.027841796875
# stage2_heatmaps_loss: 64.5679521560669
# Iter: 2400
# stage1_pafs_loss:     149.84286567687988
# stage1_heatmaps_loss: 66.12516372680665
# stage2_pafs_loss:     148.56244621276855
# stage2_heatmaps_loss: 64.49771034240723
# Iter: 2500
# stage1_pafs_loss:     147.42928817749024
# stage1_heatmaps_loss: 65.86201210021973
# stage2_pafs_loss:     146.08999832153322
# stage2_heatmaps_loss: 64.09984012603759
# Iter: 2600
# stage1_pafs_loss:     147.71707817077638
# stage1_heatmaps_loss: 65.65646186828613
# stage2_pafs_loss:     146.22123336791992
# stage2_heatmaps_loss: 63.8450768661499
# Iter: 2700
# stage1_pafs_loss:     147.36439514160156
# stage1_heatmaps_loss: 65.32760154724122
# stage2_pafs_loss:     146.01193183898926
# stage2_heatmaps_loss: 63.73903205871582
# Iter: 2800
# stage1_pafs_loss:     147.33537857055663
# stage1_heatmaps_loss: 65.27267078399659
# stage2_pafs_loss:     145.77969467163086
# stage2_heatmaps_loss: 63.495312156677244
# Iter: 2900
# stage1_pafs_loss:     147.2904126739502
# stage1_heatmaps_loss: 65.16891723632813
# stage2_pafs_loss:     145.7810029602051
# stage2_heatmaps_loss: 63.55526905059814
# Iter: 3000
# stage1_pafs_loss:     145.12568115234376
# stage1_heatmaps_loss: 63.11450885772705
# stage2_pafs_loss:     143.50298805236815
# stage2_heatmaps_loss: 61.48250057220459
# Iter: 3100
# stage1_pafs_loss:     150.92554252624512
# stage1_heatmaps_loss: 66.1037068939209
# stage2_pafs_loss:     149.14640029907227
# stage2_heatmaps_loss: 64.39180938720703
# Iter: 3200
# stage1_pafs_loss:     146.41748947143554
# stage1_heatmaps_loss: 64.31709323883057
# stage2_pafs_loss:     144.64294441223146
# stage2_heatmaps_loss: 62.58584659576416
# Iter: 3300
# stage1_pafs_loss:     146.1991059112549
# stage1_heatmaps_loss: 64.43504245758056
# stage2_pafs_loss:     144.37784309387206
# stage2_heatmaps_loss: 62.618233070373535
# Iter: 3400
# stage1_pafs_loss:     147.15941261291505
# stage1_heatmaps_loss: 64.08504009246826
# stage2_pafs_loss:     145.24766815185546
# stage2_heatmaps_loss: 62.419829788208006
# Iter: 3500
# stage1_pafs_loss:     146.08299751281737
# stage1_heatmaps_loss: 63.48829330444336
# stage2_pafs_loss:     143.95276863098144
# stage2_heatmaps_loss: 61.69584800720215
# Iter: 3600
# stage1_pafs_loss:     149.84746925354003
# stage1_heatmaps_loss: 64.72146335601806
# stage2_pafs_loss:     147.64118492126465
# stage2_heatmaps_loss: 62.764923095703125
# Iter: 3700
# stage1_pafs_loss:     142.2779093170166
# stage1_heatmaps_loss: 61.416152458190915
# stage2_pafs_loss:     139.90636207580567
# stage2_heatmaps_loss: 59.4563423538208
# Iter: 3800
# stage1_pafs_loss:     148.7694603729248
# stage1_heatmaps_loss: 64.57822021484375
# stage2_pafs_loss:     146.26929260253905
# stage2_heatmaps_loss: 62.58829387664795
# Iter: 3900
# stage1_pafs_loss:     144.76858512878417
# stage1_heatmaps_loss: 62.67822299957275
# stage2_pafs_loss:     142.2429141998291
# stage2_heatmaps_loss: 60.82805633544922
# Iter: 4000
# stage1_pafs_loss:     145.69965911865233
# stage1_heatmaps_loss: 62.84510330200195
# stage2_pafs_loss:     142.8321036529541
# stage2_heatmaps_loss: 60.77153205871582
# Iter: 4100
# stage1_pafs_loss:     146.77344093322753
# stage1_heatmaps_loss: 62.736755294799806
# stage2_pafs_loss:     143.84461418151855
# stage2_heatmaps_loss: 60.69428592681885
# Iter: 4200
# stage1_pafs_loss:     108.32061828613281
# stage1_heatmaps_loss: 46.98908847808838
# stage2_pafs_loss:     106.16946952819825
# stage2_heatmaps_loss: 45.46317024230957
# Iter: 4300
# stage1_pafs_loss:     147.2447282409668
# stage1_heatmaps_loss: 62.61425422668457
# stage2_pafs_loss:     143.99485221862793
# stage2_heatmaps_loss: 60.3568302154541
# Iter: 4400
# stage1_pafs_loss:     145.64170455932617
# stage1_heatmaps_loss: 62.0072592163086
# stage2_pafs_loss:     142.40517471313476
# stage2_heatmaps_loss: 59.71892101287842
# Iter: 4500
# stage1_pafs_loss:     144.23755561828614
# stage1_heatmaps_loss: 61.28524673461914
# stage2_pafs_loss:     141.00179901123047
# stage2_heatmaps_loss: 58.988676109313964
# Iter: 4600
# stage1_pafs_loss:     143.88148719787597
# stage1_heatmaps_loss: 61.080884284973145
# stage2_pafs_loss:     140.38332962036134
# stage2_heatmaps_loss: 58.619153861999514
# Iter: 4700
# stage1_pafs_loss:     144.88033531188964
# stage1_heatmaps_loss: 61.59345344543457
# stage2_pafs_loss:     141.2325831604004
# stage2_heatmaps_loss: 59.10944370269775
# Iter: 4800
# stage1_pafs_loss:     143.76127166748046
# stage1_heatmaps_loss: 60.35197132110596
# stage2_pafs_loss:     140.00894622802736
# stage2_heatmaps_loss: 58.06582210540771
# Iter: 4900
# stage1_pafs_loss:     139.91694885253906
# stage1_heatmaps_loss: 58.874706726074216
# stage2_pafs_loss:     136.3850552368164
# stage2_heatmaps_loss: 56.659590606689456
# Iter: 5000
# stage1_pafs_loss:     145.95211593627928
# stage1_heatmaps_loss: 61.54477710723877
# stage2_pafs_loss:     142.09420616149902
# stage2_heatmaps_loss: 59.17187633514404
# Validation...
# Running test for keypoints results.
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!"

# %%
# Out:
# ['hello_a_102.jpg',
#  'hello_a_108.jpg',
#  'hello_a_114.jpg',
#  'hello_a_12.jpg',
#  'hello_a_120.jpg',
#  'hello_a_126.jpg',
#  'hello_a_132.jpg',
#  'hello_a_138.jpg',
#  'hello_a_144.jpg',
#  'hello_a_150.jpg',
#  'hello_a_156.jpg',
#  'hello_a_162.jpg',
#  'hello_a_168.jpg',
#  'hello_a_174.jpg',
#  'hello_a_18.jpg',
#  'hello_a_24.jpg',
#  'hello_a_30.jpg',
#  'hello_a_36.jpg',
#  'hello_a_42.jpg',
#  'hello_a_48.jpg',
#  'hello_a_54.jpg',
#  'hello_a_6.jpg',
#  'hello_a_60.jpg',
#  'hello_a_66.jpg',
#  'hello_a_72.jpg',
#  'hello_a_78.jpg',
#  'hello_a_84.jpg',
#  'hello_a_90.jpg',
#  'hello_a_96.jpg']
